# %% [markdown]
# D2 = P01
# D1 = P08
# D3 = P22

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/PROGETTO_MLDL/actionNet/ ./act_data

# %%
#!rm -r act_data/actionNet

# %%
import zipfile

zip_ref = zipfile.ZipFile("act_data/S04_01.zip", 'r')

# %%
listOfFileNames = zip_ref.namelist()
   # Iterate over the file names
for fileName in listOfFileNames:
   zip_ref.extract(fileName, 'act_data')

# %%
#!cp -r act_data/S04_01 /content/drive/MyDrive/PROGETTO_MLDL/actionNet/

# %%
# Clone the public repository (or your repository)
# !git clone https://github.com/angrytako/deep-learning-egovision.git
# Out:
# Cloning into 'deep-learning-egovision'...
# remote: Enumerating objects: 295, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 295 (delta 53), reused 55 (delta 25), pack-reused 200
# Receiving objects: 100% (295/295), 962.67 MiB | 1.61 MiB/s, done.
# Resolving deltas: 100% (141/141), done.
# Updating files: 100% (57/57), done.

# %%
# !cp -r /content/drive/MyDrive/PROGETTO_MLDL/checkpoints/saved_models  /content/deep-learning-egovision

# %%
# !cp -r act_data/S04_01  /content/deep-learning-egovision/actionNet

# %%
# !ls -r act_data/
# Out:
# saved_features	S04_01.zip  S04_01

# %%
# Install conda on Google Colab

# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...

# %%
# Create a conda environment 
# As the creation of the Conda Environment may be a slow process, you may look at the `conda-pack`
# package to store the environment in a .tar.gz archive you can store on Google Drive and restore later.

# !conda env create --name egovision -f /content/deep-learning-egovision/requirements.yaml
# Out:
# CondaValueError: prefix already exists: /usr/local/envs/egovision

# %%
# !cp /content/deep-learning-egovision/pretrained_i3d/rgb_imagenet.pt /content/deep-learning-egovision/pretrained_i3d/emg_imagenet.pt

# %%
# %%bash
# ## Features extraction
#
# cd /content/deep-learning-egovision
#
# PYTHON_PATH=/usr/local/envs/egovision/bin/python
# $PYTHON_PATH save_feat.py name=features_actionNet_train_uniform_15 \
#   config=configs/I3D_save_feat.yaml split=train \
#   dataset.shift=S0401-S0401 dataset.annotations_path=actionNet\
#   dataset.RGB.data_path=./actionNet/\
#   dataset.EMG.data_path=./actionNet/\
#   modality=["RGB","EMG"]

# %%
# %%bash
# ## Features extraction
#
# cd /content/deep-learning-egovision
#
# PYTHON_PATH=/usr/local/envs/egovision/bin/python
# $PYTHON_PATH train_classifier.py name=lstm_emg_actionNet_train_uniform_15 \
#   dataset.shift=S0401-S0401 dataset.annotations_path=actionNet\
#   dataset.EMG.data_path=./actionNet/\
#   modality=["EMG"]
# Out:
# 2023-06-11 11:21:48 LOG INFO Running with parameters:
#   action: train
#   name: lstm_emg_actionNet_train_uniform_15
#   modality: ['EMG']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: None
#   logname: None
#   models_dir: saved_models/lstm_emg_actionNet_train_uniform_15/Jun11_11-21-45
#   need_clips: False
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 5
#     dense_sampling:
#       RGB: False
#     num_frames_per_clip:
#       RGB: 15
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: False
#     num_frames_per_clip:
#       RGB: 15
#   dataset:
#     annotations_path: actionNet
#     shift: S0401-S0401
#     workers: 4
#     stride: 2
#     resolution: 224
#     RGB:
#       data_path: ./saved_features/
#       tmpl: img_{:010d}.jpg
#       features_name: features_D2_uniform_15
#     EMG:
#       data_path: ./actionNet/
#       features_name: features_actionNet_test_uniform_15
#     Event:
#       rgb4e: 6
#   models:
#     RGB:
#       model: Transformer
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       n_features: 1024
#       hidden_size: 128
#       num_layers: 3
#     EMG:
#       model: Transformer
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       n_features: 400
#       hidden_size: 128
#       num_layers: 3
#   experiment_dir: lstm_emg_actionNet_train_uniform_15/Jun11_11-21-45
#   log_dir: Experiment_logs/lstm_emg_actionNet_train_uniform_15/Jun11_11-21-45
#   logfile: Experiment_logs/lstm_emg_actionNet_train_uniform_15/Jun11_11-21-45/train.log
# 2023-06-11 11:21:48 LOG INFO Instantiating models per modality
# 2023-06-11 11:21:48 LOG INFO Transformer Net	Modality: EMG
# 2023-06-11 11:21:50 LOG INFO Dataloader for S0401-train with 47 samples generated
# /usr/local/envs/egovision/lib/python3.7/site-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 2023-06-11 11:21:50 LOG INFO Dataloader for S0401-val with 12 samples generated
# /usr/local/envs/egovision/lib/python3.7/site-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 2023-06-11 11:21:50 LOG INFO Iteration 0/20000 batch retrieved! Elapsed time = 0.0 m 0.041488 s
# 2023-06-11 11:21:51 LOG INFO Iteration 1/20000 batch retrieved! Elapsed time = 0.0 m 0.242164 s
# 2023-06-11 11:21:51 LOG INFO Iteration 2/20000 batch retrieved! Elapsed time = 0.0 m 0.196237 s
# 2023-06-11 11:21:52 LOG INFO Iteration 3/20000 batch retrieved! Elapsed time = 0.0 m 0.188265 s
# 2023-06-11 11:21:52 LOG INFO [1/5000]	last Verb loss: 0.1240	Mean verb loss: 0.1292	Acc@1: 12.50%	AccMean@1: 7.66%
# 2023-06-11 11:21:52 LOG INFO Iteration 4/20000 batch retrieved! Elapsed time = 0.0 m 0.201676 s
# 2023-06-11 11:21:52 LOG INFO Iteration 5/20000 batch retrieved! Elapsed time = 0.0 m 0.193325 s
# 2023-06-11 11:21:52 LOG INFO Iteration 6/20000 batch retrieved! Elapsed time = 0.0 m 0.203952 s
# 2023-06-11 11:21:53 LOG INFO Iteration 7/20000 batch retrieved! Elapsed time = 0.0 m 0.208778 s
# 2023-06-11 11:21:53 LOG INFO [2/5000]	last Verb loss: 0.1188	Mean verb loss: 0.1185	Acc@1: 18.75%	AccMean@1: 15.62%
# 2023-06-11 11:21:53 LOG INFO Iteration 8/20000 batch retrieved! Elapsed time = 0.0 m 0.218532 s
# 2023-06-11 11:21:53 LOG INFO Iteration 9/20000 batch retrieved! Elapsed time = 0.0 m 0.206236 s
# 2023-06-11 11:21:53 LOG INFO Iteration 10/20000 batch retrieved! Elapsed time = 0.0 m 0.204245 s
# 2023-06-11 11:21:54 LOG INFO Iteration 11/20000 batch retrieved! Elapsed time = 0.0 m 0.20567 s
# 2023-06-11 11:21:54 LOG INFO [3/5000]	last Verb loss: 0.1129	Mean verb loss: 0.1112	Acc@1: 21.88%	AccMean@1: 20.31%
# 2023-06-11 11:21:54 LOG INFO Iteration 12/20000 batch retrieved! Elapsed time = 0.0 m 0.200942 s
# 2023-06-11 11:21:54 LOG INFO Iteration 13/20000 batch retrieved! Elapsed time = 0.0 m 0.207976 s
# 2023-06-11 11:21:54 LOG INFO Iteration 14/20000 batch retrieved! Elapsed time = 0.0 m 0.203136 s
# 2023-06-11 11:21:55 LOG INFO Iteration 15/20000 batch retrieved! Elapsed time = 0.0 m 0.214023 s
# 2023-06-11 11:21:55 LOG INFO [4/5000]	last Verb loss: 0.1087	Mean verb loss: 0.1087	Acc@1: 15.62%	AccMean@1: 21.41%
# 2023-06-11 11:21:55 LOG INFO Iteration 16/20000 batch retrieved! Elapsed time = 0.0 m 0.210043 s
# 2023-06-11 11:21:55 LOG INFO Iteration 17/20000 batch retrieved! Elapsed time = 0.0 m 0.228777 s
# 2023-06-11 11:21:55 LOG INFO Iteration 18/20000 batch retrieved! Elapsed time = 0.0 m 0.21417 s
# 2023-06-11 11:21:56 LOG INFO Iteration 19/20000 batch retrieved! Elapsed time = 0.0 m 0.22864 s
# 2023-06-11 11:21:56 LOG INFO [5/5000]	last Verb loss: 0.1098	Mean verb loss: 0.1095	Acc@1: 21.88%	AccMean@1: 21.09%
# 2023-06-11 11:21:56 LOG INFO Iteration 20/20000 batch retrieved! Elapsed time = 0.0 m 0.195532 s
# 2023-06-11 11:21:56 LOG INFO Iteration 21/20000 batch retrieved! Elapsed time = 0.0 m 0.202957 s
# 2023-06-11 11:21:56 LOG INFO Iteration 22/20000 batch retrieved! Elapsed time = 0.0 m 0.202462 s
# 2023-06-11 11:21:57 LOG INFO Iteration 23/20000 batch retrieved! Elapsed time = 0.0 m 0.203967 s
# 2023-06-11 11:21:57 LOG INFO [6/5000]	last Verb loss: 0.0959	Mean verb loss: 0.1044	Acc@1: 31.25%	AccMean@1: 24.84%
# 2023-06-11 11:21:57 LOG INFO Iteration 24/20000 batch retrieved! Elapsed time = 0.0 m 0.216415 s
# 2023-06-11 11:21:57 LOG INFO Iteration 25/20000 batch retrieved! Elapsed time = 0.0 m 0.197979 s
# 2023-06-11 11:21:57 LOG INFO Iteration 26/20000 batch retrieved! Elapsed time = 0.0 m 0.200657 s
# 2023-06-11 11:21:58 LOG INFO Iteration 27/20000 batch retrieved! Elapsed time = 0.0 m 0.20179 s
# 2023-06-11 11:21:58 LOG INFO [7/5000]	last Verb loss: 0.1010	Mean verb loss: 0.1083	Acc@1: 25.00%	AccMean@1: 22.03%
# 2023-06-11 11:21:58 LOG INFO Iteration 28/20000 batch retrieved! Elapsed time = 0.0 m 0.206688 s
# 2023-06-11 11:21:58 LOG INFO Iteration 29/20000 batch retrieved! Elapsed time = 0.0 m 0.210308 s
# 2023-06-11 11:21:58 LOG INFO Iteration 30/20000 batch retrieved! Elapsed time = 0.0 m 0.20787 s
# 2023-06-11 11:21:59 LOG INFO Iteration 31/20000 batch retrieved! Elapsed time = 0.0 m 0.208745 s
# 2023-06-11 11:21:59 LOG INFO [8/5000]	last Verb loss: 0.1034	Mean verb loss: 0.1069	Acc@1: 21.88%	AccMean@1: 21.41%
# 2023-06-11 11:21:59 LOG INFO Iteration 32/20000 batch retrieved! Elapsed time = 0.0 m 0.207526 s
# 2023-06-11 11:21:59 LOG INFO Iteration 33/20000 batch retrieved! Elapsed time = 0.0 m 0.20501 s
# 2023-06-11 11:21:59 LOG INFO Iteration 34/20000 batch retrieved! Elapsed time = 0.0 m 0.193349 s
# 2023-06-11 11:22:00 LOG INFO Iteration 35/20000 batch retrieved! Elapsed time = 0.0 m 0.203322 s
# 2023-06-11 11:22:00 LOG INFO [9/5000]	last Verb loss: 0.0972	Mean verb loss: 0.1051	Acc@1: 25.00%	AccMean@1: 21.88%
# 2023-06-11 11:22:00 LOG INFO Iteration 36/20000 batch retrieved! Elapsed time = 0.0 m 0.212281 s
# 2023-06-11 11:22:00 LOG INFO Iteration 37/20000 batch retrieved! Elapsed time = 0.0 m 0.202023 s
# 2023-06-11 11:22:00 LOG INFO Iteration 38/20000 batch retrieved! Elapsed time = 0.0 m 0.219768 s
# 2023-06-11 11:22:01 LOG INFO Iteration 39/20000 batch retrieved! Elapsed time = 0.0 m 0.206282 s
# 2023-06-11 11:22:01 LOG INFO [10/5000]	last Verb loss: 0.0946	Mean verb loss: 0.1063	Acc@1: 25.00%	AccMean@1: 20.94%
# 2023-06-11 11:22:01 LOG INFO Iteration 40/20000 batch retrieved! Elapsed time = 0.0 m 0.221441 s
# 2023-06-11 11:22:01 LOG INFO Iteration 41/20000 batch retrieved! Elapsed time = 0.0 m 0.221801 s
# 2023-06-11 11:22:02 LOG INFO Iteration 42/20000 batch retrieved! Elapsed time = 0.0 m 0.311625 s
# 2023-06-11 11:22:02 LOG INFO Iteration 43/20000 batch retrieved! Elapsed time = 0.0 m 0.321216 s
# 2023-06-11 11:22:02 LOG INFO [11/5000]	last Verb loss: 0.0959	Mean verb loss: 0.1047	Acc@1: 40.62%	AccMean@1: 22.50%
# 2023-06-11 11:22:02 LOG INFO Iteration 44/20000 batch retrieved! Elapsed time = 0.0 m 0.315144 s
# 2023-06-11 11:22:03 LOG INFO Iteration 45/20000 batch retrieved! Elapsed time = 0.0 m 0.323595 s
# 2023-06-11 11:22:03 LOG INFO Iteration 46/20000 batch retrieved! Elapsed time = 0.0 m 0.331509 s
# 2023-06-11 11:22:04 LOG INFO Iteration 47/20000 batch retrieved! Elapsed time = 0.0 m 0.343671 s
# 2023-06-11 11:22:04 LOG INFO [12/5000]	last Verb loss: 0.1044	Mean verb loss: 0.1054	Acc@1: 18.75%	AccMean@1: 23.59%
# 2023-06-11 11:22:04 LOG INFO Iteration 48/20000 batch retrieved! Elapsed time = 0.0 m 0.311796 s
# 2023-06-11 11:22:04 LOG INFO Iteration 49/20000 batch retrieved! Elapsed time = 0.0 m 0.357202 s
# 2023-06-11 11:22:05 LOG INFO Iteration 50/20000 batch retrieved! Elapsed time = 0.0 m 0.325283 s
# 2023-06-11 11:22:05 LOG INFO Iteration 51/20000 batch retrieved! Elapsed time = 0.0 m 0.3279 s
# 2023-06-11 11:22:05 LOG INFO [13/5000]	last Verb loss: 0.0988	Mean verb loss: 0.1022	Acc@1: 25.00%	AccMean@1: 25.47%
# 2023-06-11 11:22:05 LOG INFO Iteration 52/20000 batch retrieved! Elapsed time = 0.0 m 0.328907 s
# 2023-06-11 11:22:06 LOG INFO Iteration 53/20000 batch retrieved! Elapsed time = 0.0 m 0.3252 s
# 2023-06-11 11:22:06 LOG INFO Iteration 54/20000 batch retrieved! Elapsed time = 0.0 m 0.322623 s
# 2023-06-11 11:22:07 LOG INFO Iteration 55/20000 batch retrieved! Elapsed time = 0.0 m 0.297024 s
# 2023-06-11 11:22:07 LOG INFO [14/5000]	last Verb loss: 0.0884	Mean verb loss: 0.0974	Acc@1: 28.12%	AccMean@1: 31.09%
# 2023-06-11 11:22:07 LOG INFO Iteration 56/20000 batch retrieved! Elapsed time = 0.0 m 0.303251 s
# 2023-06-11 11:22:07 LOG INFO Iteration 57/20000 batch retrieved! Elapsed time = 0.0 m 0.299794 s
# 2023-06-11 11:22:08 LOG INFO Iteration 58/20000 batch retrieved! Elapsed time = 0.0 m 0.313973 s
# 2023-06-11 11:22:08 LOG INFO Iteration 59/20000 batch retrieved! Elapsed time = 0.0 m 0.322758 s
# 2023-06-11 11:22:08 LOG INFO [15/5000]	last Verb loss: 0.0969	Mean verb loss: 0.1007	Acc@1: 25.00%	AccMean@1: 28.91%
# 2023-06-11 11:22:09 LOG INFO Iteration 60/20000 batch retrieved! Elapsed time = 0.0 m 0.342113 s
# 2023-06-11 11:22:09 LOG INFO Iteration 61/20000 batch retrieved! Elapsed time = 0.0 m 0.315881 s
# 2023-06-11 11:22:09 LOG INFO Iteration 62/20000 batch retrieved! Elapsed time = 0.0 m 0.321815 s
# 2023-06-11 11:22:10 LOG INFO Iteration 63/20000 batch retrieved! Elapsed time = 0.0 m 0.317843 s
# 2023-06-11 11:22:10 LOG INFO [16/5000]	last Verb loss: 0.1010	Mean verb loss: 0.1015	Acc@1: 21.88%	AccMean@1: 24.84%
# 2023-06-11 11:22:10 LOG INFO Iteration 64/20000 batch retrieved! Elapsed time = 0.0 m 0.348872 s
# 2023-06-11 11:22:11 LOG INFO Iteration 65/20000 batch retrieved! Elapsed time = 0.0 m 0.311019 s
# 2023-06-11 11:22:11 LOG INFO Iteration 66/20000 batch retrieved! Elapsed time = 0.0 m 0.340384 s
# 2023-06-11 11:22:11 LOG INFO Iteration 67/20000 batch retrieved! Elapsed time = 0.0 m 0.312755 s
# 2023-06-11 11:22:11 LOG INFO [17/5000]	last Verb loss: 0.0873	Mean verb loss: 0.0978	Acc@1: 34.38%	AccMean@1: 28.44%
# 2023-06-11 11:22:12 LOG INFO Iteration 68/20000 batch retrieved! Elapsed time = 0.0 m 0.317406 s
# 2023-06-11 11:22:12 LOG INFO Iteration 69/20000 batch retrieved! Elapsed time = 0.0 m 0.30267 s
# 2023-06-11 11:22:12 LOG INFO Iteration 70/20000 batch retrieved! Elapsed time = 0.0 m 0.324647 s
# 2023-06-11 11:22:13 LOG INFO Iteration 71/20000 batch retrieved! Elapsed time = 0.0 m 0.301621 s
# 2023-06-11 11:22:13 LOG INFO [18/5000]	last Verb loss: 0.0920	Mean verb loss: 0.1032	Acc@1: 31.25%	AccMean@1: 23.91%
# 2023-06-11 11:22:13 LOG INFO Iteration 72/20000 batch retrieved! Elapsed time = 0.0 m 0.333782 s
# 2023-06-11 11:22:14 LOG INFO Iteration 73/20000 batch retrieved! Elapsed time = 0.0 m 0.321566 s
# 2023-06-11 11:22:14 LOG INFO Iteration 74/20000 batch retrieved! Elapsed time = 0.0 m 0.314825 s
# 2023-06-11 11:22:14 LOG INFO Iteration 75/20000 batch retrieved! Elapsed time = 0.0 m 0.271871 s
# 2023-06-11 11:22:14 LOG INFO [19/5000]	last Verb loss: 0.0987	Mean verb loss: 0.1002	Acc@1: 31.25%	AccMean@1: 27.66%
# 2023-06-11 11:22:15 LOG INFO Iteration 76/20000 batch retrieved! Elapsed time = 0.0 m 0.214725 s
# 2023-06-11 11:22:15 LOG INFO Iteration 77/20000 batch retrieved! Elapsed time = 0.0 m 0.202494 s
# 2023-06-11 11:22:15 LOG INFO Iteration 78/20000 batch retrieved! Elapsed time = 0.0 m 0.214982 s
# 2023-06-11 11:22:15 LOG INFO Iteration 79/20000 batch retrieved! Elapsed time = 0.0 m 0.208175 s
# 2023-06-11 11:22:15 LOG INFO [20/5000]	last Verb loss: 0.0941	Mean verb loss: 0.0993	Acc@1: 21.88%	AccMean@1: 24.38%
# 2023-06-11 11:22:16 LOG INFO Iteration 80/20000 batch retrieved! Elapsed time = 0.0 m 0.236714 s
# 2023-06-11 11:22:16 LOG INFO Iteration 81/20000 batch retrieved! Elapsed time = 0.0 m 0.212704 s
# 2023-06-11 11:22:16 LOG INFO Iteration 82/20000 batch retrieved! Elapsed time = 0.0 m 0.207029 s
# 2023-06-11 11:22:16 LOG INFO Iteration 83/20000 batch retrieved! Elapsed time = 0.0 m 0.201836 s
# 2023-06-11 11:22:16 LOG INFO [21/5000]	last Verb loss: 0.0942	Mean verb loss: 0.0994	Acc@1: 28.12%	AccMean@1: 26.09%
# 2023-06-11 11:22:17 LOG INFO Iteration 84/20000 batch retrieved! Elapsed time = 0.0 m 0.202252 s
# 2023-06-11 11:22:17 LOG INFO Iteration 85/20000 batch retrieved! Elapsed time = 0.0 m 0.202407 s
# 2023-06-11 11:22:17 LOG INFO Iteration 86/20000 batch retrieved! Elapsed time = 0.0 m 0.204992 s
# 2023-06-11 11:22:17 LOG INFO Iteration 87/20000 batch retrieved! Elapsed time = 0.0 m 0.203737 s
# 2023-06-11 11:22:17 LOG INFO [22/5000]	last Verb loss: 0.0842	Mean verb loss: 0.0984	Acc@1: 43.75%	AccMean@1: 25.47%
# 2023-06-11 11:22:18 LOG INFO Iteration 88/20000 batch retrieved! Elapsed time = 0.0 m 0.202171 s
# 2023-06-11 11:22:18 LOG INFO Iteration 89/20000 batch retrieved! Elapsed time = 0.0 m 0.216265 s
# 2023-06-11 11:22:18 LOG INFO Iteration 90/20000 batch retrieved! Elapsed time = 0.0 m 0.225748 s
# 2023-06-11 11:22:18 LOG INFO Iteration 91/20000 batch retrieved! Elapsed time = 0.0 m 0.214274 s
# 2023-06-11 11:22:18 LOG INFO [23/5000]	last Verb loss: 0.0968	Mean verb loss: 0.1045	Acc@1: 28.12%	AccMean@1: 23.28%
# 2023-06-11 11:22:19 LOG INFO Iteration 92/20000 batch retrieved! Elapsed time = 0.0 m 0.228944 s
# 2023-06-11 11:22:19 LOG INFO Iteration 93/20000 batch retrieved! Elapsed time = 0.0 m 0.216706 s
# 2023-06-11 11:22:19 LOG INFO Iteration 94/20000 batch retrieved! Elapsed time = 0.0 m 0.21363 s
# 2023-06-11 11:22:19 LOG INFO Iteration 95/20000 batch retrieved! Elapsed time = 0.0 m 0.197319 s
# 2023-06-11 11:22:19 LOG INFO [24/5000]	last Verb loss: 0.0979	Mean verb loss: 0.1016	Acc@1: 28.12%	AccMean@1: 27.66%
# 2023-06-11 11:22:20 LOG INFO Iteration 96/20000 batch retrieved! Elapsed time = 0.0 m 0.219965 s
# 2023-06-11 11:22:20 LOG INFO Iteration 97/20000 batch retrieved! Elapsed time = 0.0 m 0.197646 s
# 2023-06-11 11:22:20 LOG INFO Iteration 98/20000 batch retrieved! Elapsed time = 0.0 m 0.207913 s
# 2023-06-11 11:22:20 LOG INFO Iteration 99/20000 batch retrieved! Elapsed time = 0.0 m 0.212515 s
# 2023-06-11 11:22:20 LOG INFO [25/5000]	last Verb loss: 0.0867	Mean verb loss: 0.0981	Acc@1: 43.75%	AccMean@1: 29.06%
# 2023-06-11 11:22:21 LOG INFO Iteration 100/20000 batch retrieved! Elapsed time = 0.0 m 0.218865 s
# 2023-06-11 11:22:21 LOG INFO Iteration 101/20000 batch retrieved! Elapsed time = 0.0 m 0.210174 s
# 2023-06-11 11:22:21 LOG INFO Iteration 102/20000 batch retrieved! Elapsed time = 0.0 m 0.207947 s
# 2023-06-11 11:22:21 LOG INFO Iteration 103/20000 batch retrieved! Elapsed time = 0.0 m 0.196096 s
# 2023-06-11 11:22:21 LOG INFO [26/5000]	last Verb loss: 0.0867	Mean verb loss: 0.0995	Acc@1: 40.62%	AccMean@1: 27.03%
# 2023-06-11 11:22:22 LOG INFO Iteration 104/20000 batch retrieved! Elapsed time = 0.0 m 0.208313 s
# 2023-06-11 11:22:22 LOG INFO Iteration 105/20000 batch retrieved! Elapsed time = 0.0 m 0.196684 s
# 2023-06-11 11:22:22 LOG INFO Iteration 106/20000 batch retrieved! Elapsed time = 0.0 m 0.199763 s
# 2023-06-11 11:22:22 LOG INFO Iteration 107/20000 batch retrieved! Elapsed time = 0.0 m 0.198253 s
# 2023-06-11 11:22:22 LOG INFO [27/5000]	last Verb loss: 0.0949	Mean verb loss: 0.0972	Acc@1: 31.25%	AccMean@1: 28.75%
# 2023-06-11 11:22:23 LOG INFO Iteration 108/20000 batch retrieved! Elapsed time = 0.0 m 0.206847 s
# 2023-06-11 11:22:23 LOG INFO Iteration 109/20000 batch retrieved! Elapsed time = 0.0 m 0.214422 s
# 2023-06-11 11:22:23 LOG INFO Iteration 110/20000 batch retrieved! Elapsed time = 0.0 m 0.202053 s
# 2023-06-11 11:22:23 LOG INFO Iteration 111/20000 batch retrieved! Elapsed time = 0.0 m 0.212016 s
# 2023-06-11 11:22:23 LOG INFO [28/5000]	last Verb loss: 0.0938	Mean verb loss: 0.1008	Acc@1: 31.25%	AccMean@1: 26.88%
# 2023-06-11 11:22:24 LOG INFO Iteration 112/20000 batch retrieved! Elapsed time = 0.0 m 0.217065 s
# 2023-06-11 11:22:24 LOG INFO Iteration 113/20000 batch retrieved! Elapsed time = 0.0 m 0.222786 s
# 2023-06-11 11:22:24 LOG INFO Iteration 114/20000 batch retrieved! Elapsed time = 0.0 m 0.2131 s
# 2023-06-11 11:22:25 LOG INFO Iteration 115/20000 batch retrieved! Elapsed time = 0.0 m 0.286624 s
# 2023-06-11 11:22:25 LOG INFO [29/5000]	last Verb loss: 0.0873	Mean verb loss: 0.1008	Acc@1: 43.75%	AccMean@1: 27.03%
# 2023-06-11 11:22:25 LOG INFO Iteration 116/20000 batch retrieved! Elapsed time = 0.0 m 0.345695 s
# 2023-06-11 11:22:25 LOG INFO Iteration 117/20000 batch retrieved! Elapsed time = 0.0 m 0.306713 s
# 2023-06-11 11:22:26 LOG INFO Iteration 118/20000 batch retrieved! Elapsed time = 0.0 m 0.325392 s
# 2023-06-11 11:22:26 LOG INFO Iteration 119/20000 batch retrieved! Elapsed time = 0.0 m 0.335188 s
# 2023-06-11 11:22:26 LOG INFO [30/5000]	last Verb loss: 0.0896	Mean verb loss: 0.0979	Acc@1: 37.50%	AccMean@1: 27.97%
# 2023-06-11 11:22:26 LOG INFO Iteration 120/20000 batch retrieved! Elapsed time = 0.0 m 0.342909 s
# 2023-06-11 11:22:27 LOG INFO Iteration 121/20000 batch retrieved! Elapsed time = 0.0 m 0.310706 s
# 2023-06-11 11:22:27 LOG INFO Iteration 122/20000 batch retrieved! Elapsed time = 0.0 m 0.334881 s
# 2023-06-11 11:22:28 LOG INFO Iteration 123/20000 batch retrieved! Elapsed time = 0.0 m 0.362343 s
# 2023-06-11 11:22:28 LOG INFO [31/5000]	last Verb loss: 0.0976	Mean verb loss: 0.0999	Acc@1: 25.00%	AccMean@1: 26.88%
# 2023-06-11 11:22:28 LOG INFO Iteration 124/20000 batch retrieved! Elapsed time = 0.0 m 0.345516 s
# 2023-06-11 11:22:28 LOG INFO Iteration 125/20000 batch retrieved! Elapsed time = 0.0 m 0.30884 s
# 2023-06-11 11:22:29 LOG INFO Iteration 126/20000 batch retrieved! Elapsed time = 0.0 m 0.294697 s
# 2023-06-11 11:22:29 LOG INFO Iteration 127/20000 batch retrieved! Elapsed time = 0.0 m 0.322088 s
# 2023-06-11 11:22:29 LOG INFO [32/5000]	last Verb loss: 0.0893	Mean verb loss: 0.0981	Acc@1: 40.62%	AccMean@1: 29.06%
# 2023-06-11 11:22:30 LOG INFO Iteration 128/20000 batch retrieved! Elapsed time = 0.0 m 0.315619 s
# 2023-06-11 11:22:30 LOG INFO Iteration 129/20000 batch retrieved! Elapsed time = 0.0 m 0.301839 s
# 2023-06-11 11:22:30 LOG INFO Iteration 130/20000 batch retrieved! Elapsed time = 0.0 m 0.342968 s
# 2023-06-11 11:22:31 LOG INFO Iteration 131/20000 batch retrieved! Elapsed time = 0.0 m 0.296633 s
# 2023-06-11 11:22:31 LOG INFO [33/5000]	last Verb loss: 0.0853	Mean verb loss: 0.0977	Acc@1: 34.38%	AccMean@1: 27.03%
# 2023-06-11 11:22:31 LOG INFO Iteration 132/20000 batch retrieved! Elapsed time = 0.0 m 0.305146 s
# 2023-06-11 11:22:31 LOG INFO Iteration 133/20000 batch retrieved! Elapsed time = 0.0 m 0.324782 s
# 2023-06-11 11:22:32 LOG INFO Iteration 134/20000 batch retrieved! Elapsed time = 0.0 m 0.307838 s
# 2023-06-11 11:22:32 LOG INFO Iteration 135/20000 batch retrieved! Elapsed time = 0.0 m 0.308116 s
# 2023-06-11 11:22:32 LOG INFO [34/5000]	last Verb loss: 0.1031	Mean verb loss: 0.1017	Acc@1: 21.88%	AccMean@1: 27.50%
# 2023-06-11 11:22:33 LOG INFO Iteration 136/20000 batch retrieved! Elapsed time = 0.0 m 0.343007 s
# 2023-06-11 11:22:33 LOG INFO Iteration 137/20000 batch retrieved! Elapsed time = 0.0 m 0.306225 s
# 2023-06-11 11:22:33 LOG INFO Iteration 138/20000 batch retrieved! Elapsed time = 0.0 m 0.324679 s
# 2023-06-11 11:22:34 LOG INFO Iteration 139/20000 batch retrieved! Elapsed time = 0.0 m 0.285512 s
# 2023-06-11 11:22:34 LOG INFO [35/5000]	last Verb loss: 0.0920	Mean verb loss: 0.0969	Acc@1: 25.00%	AccMean@1: 27.34%
# 2023-06-11 11:22:34 LOG INFO Iteration 140/20000 batch retrieved! Elapsed time = 0.0 m 0.298557 s
# 2023-06-11 11:22:34 LOG INFO Iteration 141/20000 batch retrieved! Elapsed time = 0.0 m 0.324331 s
# 2023-06-11 11:22:35 LOG INFO Iteration 142/20000 batch retrieved! Elapsed time = 0.0 m 0.291891 s
# 2023-06-11 11:22:35 LOG INFO Iteration 143/20000 batch retrieved! Elapsed time = 0.0 m 0.347234 s
# 2023-06-11 11:22:35 LOG INFO [36/5000]	last Verb loss: 0.0884	Mean verb loss: 0.0995	Acc@1: 28.12%	AccMean@1: 27.50%
# 2023-06-11 11:22:36 LOG INFO Iteration 144/20000 batch retrieved! Elapsed time = 0.0 m 0.303938 s
# 2023-06-11 11:22:36 LOG INFO Iteration 145/20000 batch retrieved! Elapsed time = 0.0 m 0.316123 s
# 2023-06-11 11:22:36 LOG INFO Iteration 146/20000 batch retrieved! Elapsed time = 0.0 m 0.36806 s
# 2023-06-11 11:22:37 LOG INFO Iteration 147/20000 batch retrieved! Elapsed time = 0.0 m 0.305643 s
# 2023-06-11 11:22:37 LOG INFO [37/5000]	last Verb loss: 0.0967	Mean verb loss: 0.1012	Acc@1: 34.38%	AccMean@1: 27.19%
# 2023-06-11 11:22:37 LOG INFO Iteration 148/20000 batch retrieved! Elapsed time = 0.0 m 0.317968 s
# 2023-06-11 11:22:37 LOG INFO Iteration 149/20000 batch retrieved! Elapsed time = 0.0 m 0.252408 s
# 2023-06-11 11:22:38 LOG INFO Iteration 150/20000 batch retrieved! Elapsed time = 0.0 m 0.200648 s
# 2023-06-11 11:22:38 LOG INFO Iteration 151/20000 batch retrieved! Elapsed time = 0.0 m 0.203672 s
# 2023-06-11 11:22:38 LOG INFO [38/5000]	last Verb loss: 0.0869	Mean verb loss: 0.0980	Acc@1: 43.75%	AccMean@1: 30.31%
# 2023-06-11 11:22:38 LOG INFO Iteration 152/20000 batch retrieved! Elapsed time = 0.0 m 0.206075 s
# 2023-06-11 11:22:38 LOG INFO Iteration 153/20000 batch retrieved! Elapsed time = 0.0 m 0.217664 s
# 2023-06-11 11:22:39 LOG INFO Iteration 154/20000 batch retrieved! Elapsed time = 0.0 m 0.226573 s
# 2023-06-11 11:22:39 LOG INFO Iteration 155/20000 batch retrieved! Elapsed time = 0.0 m 0.198866 s
# 2023-06-11 11:22:39 LOG INFO [39/5000]	last Verb loss: 0.0945	Mean verb loss: 0.0981	Acc@1: 34.38%	AccMean@1: 30.16%
# 2023-06-11 11:22:39 LOG INFO Iteration 156/20000 batch retrieved! Elapsed time = 0.0 m 0.212202 s
# 2023-06-11 11:22:39 LOG INFO Iteration 157/20000 batch retrieved! Elapsed time = 0.0 m 0.206156 s
# 2023-06-11 11:22:40 LOG INFO Iteration 158/20000 batch retrieved! Elapsed time = 0.0 m 0.200888 s
# 2023-06-11 11:22:40 LOG INFO Iteration 159/20000 batch retrieved! Elapsed time = 0.0 m 0.205615 s
# 2023-06-11 11:22:40 LOG INFO [40/5000]	last Verb loss: 0.0978	Mean verb loss: 0.1011	Acc@1: 28.12%	AccMean@1: 24.84%
# 2023-06-11 11:22:40 LOG INFO Iteration 160/20000 batch retrieved! Elapsed time = 0.0 m 0.209302 s
# 2023-06-11 11:22:40 LOG INFO Iteration 161/20000 batch retrieved! Elapsed time = 0.0 m 0.200577 s
# 2023-06-11 11:22:41 LOG INFO Iteration 162/20000 batch retrieved! Elapsed time = 0.0 m 0.201141 s
# 2023-06-11 11:22:41 LOG INFO Iteration 163/20000 batch retrieved! Elapsed time = 0.0 m 0.204134 s
# 2023-06-11 11:22:41 LOG INFO [41/5000]	last Verb loss: 0.0946	Mean verb loss: 0.0993	Acc@1: 28.12%	AccMean@1: 27.81%
# 2023-06-11 11:22:41 LOG INFO Iteration 164/20000 batch retrieved! Elapsed time = 0.0 m 0.200848 s
# 2023-06-11 11:22:41 LOG INFO Iteration 165/20000 batch retrieved! Elapsed time = 0.0 m 0.205089 s
# 2023-06-11 11:22:42 LOG INFO Iteration 166/20000 batch retrieved! Elapsed time = 0.0 m 0.200774 s
# 2023-06-11 11:22:42 LOG INFO Iteration 167/20000 batch retrieved! Elapsed time = 0.0 m 0.205313 s
# 2023-06-11 11:22:42 LOG INFO [42/5000]	last Verb loss: 0.0966	Mean verb loss: 0.0990	Acc@1: 28.12%	AccMean@1: 28.44%
# 2023-06-11 11:22:42 LOG INFO Iteration 168/20000 batch retrieved! Elapsed time = 0.0 m 0.212288 s
# 2023-06-11 11:22:42 LOG INFO Iteration 169/20000 batch retrieved! Elapsed time = 0.0 m 0.196997 s
# 2023-06-11 11:22:43 LOG INFO Iteration 170/20000 batch retrieved! Elapsed time = 0.0 m 0.214137 s
# 2023-06-11 11:22:43 LOG INFO Iteration 171/20000 batch retrieved! Elapsed time = 0.0 m 0.209435 s
# 2023-06-11 11:22:43 LOG INFO [43/5000]	last Verb loss: 0.0943	Mean verb loss: 0.0971	Acc@1: 37.50%	AccMean@1: 30.62%
# 2023-06-11 11:22:43 LOG INFO Iteration 172/20000 batch retrieved! Elapsed time = 0.0 m 0.209853 s
# 2023-06-11 11:22:43 LOG INFO Iteration 173/20000 batch retrieved! Elapsed time = 0.0 m 0.203009 s
# 2023-06-11 11:22:44 LOG INFO Iteration 174/20000 batch retrieved! Elapsed time = 0.0 m 0.211368 s
# 2023-06-11 11:22:44 LOG INFO Iteration 175/20000 batch retrieved! Elapsed time = 0.0 m 0.203986 s
# 2023-06-11 11:22:44 LOG INFO [44/5000]	last Verb loss: 0.0918	Mean verb loss: 0.0952	Acc@1: 28.12%	AccMean@1: 31.25%
# 2023-06-11 11:22:44 LOG INFO Iteration 176/20000 batch retrieved! Elapsed time = 0.0 m 0.211804 s
# 2023-06-11 11:22:44 LOG INFO Iteration 177/20000 batch retrieved! Elapsed time = 0.0 m 0.2087 s
# 2023-06-11 11:22:45 LOG INFO Iteration 178/20000 batch retrieved! Elapsed time = 0.0 m 0.215794 s
# 2023-06-11 11:22:45 LOG INFO Iteration 179/20000 batch retrieved! Elapsed time = 0.0 m 0.209139 s
# 2023-06-11 11:22:45 LOG INFO [45/5000]	last Verb loss: 0.0907	Mean verb loss: 0.0968	Acc@1: 28.12%	AccMean@1: 31.25%
# 2023-06-11 11:22:45 LOG INFO Iteration 180/20000 batch retrieved! Elapsed time = 0.0 m 0.211194 s
# 2023-06-11 11:22:45 LOG INFO Iteration 181/20000 batch retrieved! Elapsed time = 0.0 m 0.206894 s
# 2023-06-11 11:22:46 LOG INFO Iteration 182/20000 batch retrieved! Elapsed time = 0.0 m 0.212585 s
# 2023-06-11 11:22:46 LOG INFO Iteration 183/20000 batch retrieved! Elapsed time = 0.0 m 0.201353 s
# 2023-06-11 11:22:46 LOG INFO [46/5000]	last Verb loss: 0.0891	Mean verb loss: 0.0960	Acc@1: 37.50%	AccMean@1: 30.31%
# 2023-06-11 11:22:46 LOG INFO Iteration 184/20000 batch retrieved! Elapsed time = 0.0 m 0.211027 s
# 2023-06-11 11:22:46 LOG INFO Iteration 185/20000 batch retrieved! Elapsed time = 0.0 m 0.212977 s
# 2023-06-11 11:22:47 LOG INFO Iteration 186/20000 batch retrieved! Elapsed time = 0.0 m 0.215326 s
# 2023-06-11 11:22:47 LOG INFO Iteration 187/20000 batch retrieved! Elapsed time = 0.0 m 0.211644 s
# 2023-06-11 11:22:47 LOG INFO [47/5000]	last Verb loss: 0.0947	Mean verb loss: 0.0991	Acc@1: 31.25%	AccMean@1: 27.19%
# 2023-06-11 11:22:47 LOG INFO Iteration 188/20000 batch retrieved! Elapsed time = 0.0 m 0.21512 s
# 2023-06-11 11:22:48 LOG INFO Iteration 189/20000 batch retrieved! Elapsed time = 0.0 m 0.302324 s
# 2023-06-11 11:22:48 LOG INFO Iteration 190/20000 batch retrieved! Elapsed time = 0.0 m 0.345933 s
# 2023-06-11 11:22:48 LOG INFO Iteration 191/20000 batch retrieved! Elapsed time = 0.0 m 0.349668 s
# 2023-06-11 11:22:48 LOG INFO [48/5000]	last Verb loss: 0.0872	Mean verb loss: 0.0979	Acc@1: 37.50%	AccMean@1: 28.75%
# 2023-06-11 11:22:49 LOG INFO Iteration 192/20000 batch retrieved! Elapsed time = 0.0 m 0.352389 s
# 2023-06-11 11:22:49 LOG INFO Iteration 193/20000 batch retrieved! Elapsed time = 0.0 m 0.301788 s
# 2023-06-11 11:22:50 LOG INFO Iteration 194/20000 batch retrieved! Elapsed time = 0.0 m 0.323597 s
# 2023-06-11 11:22:50 LOG INFO Iteration 195/20000 batch retrieved! Elapsed time = 0.0 m 0.334526 s
# 2023-06-11 11:22:50 LOG INFO [49/5000]	last Verb loss: 0.0886	Mean verb loss: 0.0950	Acc@1: 40.62%	AccMean@1: 31.72%
# 2023-06-11 11:22:50 LOG INFO Iteration 196/20000 batch retrieved! Elapsed time = 0.0 m 0.334901 s
# 2023-06-11 11:22:51 LOG INFO Iteration 197/20000 batch retrieved! Elapsed time = 0.0 m 0.326052 s
# 2023-06-11 11:22:51 LOG INFO Iteration 198/20000 batch retrieved! Elapsed time = 0.0 m 0.324839 s
# 2023-06-11 11:22:51 LOG INFO Iteration 199/20000 batch retrieved! Elapsed time = 0.0 m 0.317311 s
# 2023-06-11 11:22:52 LOG INFO [50/5000]	last Verb loss: 0.0887	Mean verb loss: 0.0962	Acc@1: 34.38%	AccMean@1: 28.28%
# 2023-06-11 11:22:52 LOG ERROR Uncaught exception
# Traceback (most recent call last):
#   File "train_classifier.py", line 315, in <module>
#     main()
#   File "train_classifier.py", line 115, in main
#     train(action_classifier, train_loader, val_loader, device, num_classes)
#   File "train_classifier.py", line 222, in train
#     val_metrics = validate(action_classifier, val_loader, device, int(real_iter), num_classes)
#   File "train_classifier.py", line 289, in validate
#     if (i_val + 1) % (len(val_loader) // 5) == 0:
# ZeroDivisionError: integer division or modulo by zero
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-55-20e99aef1568> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', '## Features extraction\n\ncd /content/deep-learning-egovision\n\nPYTHON_PATH=/usr/local/envs/egovision/bin/python\n$PYTHON_PATH train_classifier.py name=lstm_emg_actionNet_train_uniform_15 \\\n  dataset.shift=S0401-S0401 dataset.annotations_path=actionNet\\\n  dataset.EMG.data_path=./actionNet/\\\n  modality=["EMG"]\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'## Features extraction\n\ncd /content/deep-learning-egovision\n\nPYTHON_PATH=/usr/local/envs/egovision/bin/python\n$PYTHON_PATH train_classifier.py name=lstm_emg_actionNet_train_uniform_15 \\\n  dataset.shift=S0401-S0401 dataset.annotations_path=actionNet\\\n  dataset.EMG.data_path=./actionNet/\\\n  modality=["EMG"]\n'' returned non-zero exit status 1.
