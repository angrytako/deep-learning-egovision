# %% [markdown]
# D2 = P01
# D1 = P08
# D3 = P22

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/PROGETTO_MLDL/actionNet/ ./act_data

# %%
#!rm -r act_data/actionNet

# %%
import zipfile

zip_ref = zipfile.ZipFile("act_data/S04_01.zip", 'r')

# %%
listOfFileNames = zip_ref.namelist()
   # Iterate over the file names
for fileName in listOfFileNames:
   zip_ref.extract(fileName, 'act_data')

# %%
#!cp -r act_data/S04_01 /content/drive/MyDrive/PROGETTO_MLDL/actionNet/

# %%
# Clone the public repository (or your repository)
# !git clone https://github.com/angrytako/deep-learning-egovision.git
# Out:
# Cloning into 'deep-learning-egovision'...
# remote: Enumerating objects: 311, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 311 (delta 64), reused 69 (delta 35), pack-reused 200
# Receiving objects: 100% (311/311), 963.92 MiB | 18.20 MiB/s, done.
# Resolving deltas: 100% (152/152), done.
# Updating files: 100% (57/57), done.

# %%
# !cp -r /content/drive/MyDrive/PROGETTO_MLDL/checkpoints/saved_models  /content/deep-learning-egovision

# %%
# !mv -r act_data/S04_01  /content/deep-learning-egovision/actionNet/S0401

# %%
# !mv /content/deep-learning-egovision/actionNet/S04_01 /content/deep-learning-egovision/actionNet/S0401

# %%
# Install conda on Google Colab

# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:17
# 🔁 Restarting kernel...

# %%
# Create a conda environment 
# As the creation of the Conda Environment may be a slow process, you may look at the `conda-pack`
# package to store the environment in a .tar.gz archive you can store on Google Drive and restore later.

# !conda env create --name egovision -f /content/deep-learning-egovision/requirements.yaml
# Out:
# done
# done
# - By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# - Enabling nb_conda_kernels...
# CONDA_PREFIX: /usr/local/envs/egovision
# Status: enabled
#
# \ Config option `kernel_spec_manager_class` not recognized by `EnableNBExtensionApp`.
# Enabling notebook extension nb_conda/main...
# Paths used for configuration of notebook:
#     	/usr/local/envs/egovision/etc/jupyter/nbconfig/notebook.d/widgetsnbextension.json
#     	/usr/local/envs/egovision/etc/jupyter/nbconfig/notebook.json
# Paths used for configuration of notebook:
#     	/usr/local/envs/egovision/etc/jupyter/nbconfig/notebook.d/widgetsnbextension.json
#       - Validating: OK
# Paths used for configuration of notebook:
#     	/usr/local/envs/egovision/etc/jupyter/nbconfig/notebook.d/widgetsnbextension.json
#     	/usr/local/envs/egovision/etc/jupyter/nbconfig/notebook.json
# Enabling tree extension nb_conda/tree...
# Paths used for configuration of tree:
#     	/usr/local/envs/egovision/etc/jupyter/nbconfig/tree.json
# Paths used for configuration of tree:
#
#       - Validating: OK
# Paths used for configuration of tree:
#     	/usr/local/envs/egovision/etc/jupyter/nbconfig/tree.json
# Config option `kernel_spec_manager_class` not recognized by `EnableServerExtensionApp`.
# Enabling: nb_conda
# - Writing config: /usr/local/envs/egovision/etc/jupyter
#     - Validating...
#       nb_conda 2.2.1 OK
#
# -
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# / Ran pip subprocess with arguments:
# ['/usr/local/envs/egovision/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting antlr4-python3-runtime==4.9.3
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: click==8.1.3 in /usr/local/envs/egovision/lib/python3.7/site-packages (from -r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 2)) (8.1.3)
# Collecting docker-pycreds==0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting einops==0.5.0
#   Downloading einops-0.5.0-py3-none-any.whl (36 kB)
# Collecting filelock==3.8.0
#   Downloading filelock-3.8.0-py3-none-any.whl (10 kB)
# Collecting gdown==4.5.3
#   Downloading gdown-4.5.3-py3-none-any.whl (14 kB)
# Collecting gitdb==4.0.9
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 3.5 MB/s eta 0:00:00
# Collecting gitpython==3.1.29
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.5/182.5 kB 14.5 MB/s eta 0:00:00
# Collecting huggingface-hub==0.10.1
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 19.0 MB/s eta 0:00:00
# Collecting importlib-metadata==5.0.0
#   Downloading importlib_metadata-5.0.0-py3-none-any.whl (21 kB)
# Collecting kneed==0.8.1
#   Downloading kneed-0.8.1-py2.py3-none-any.whl (10 kB)
# Collecting omegaconf==2.2.3
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 10.7 MB/s eta 0:00:00
# Collecting pathtools==0.1.2
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting promise==2.3
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting protobuf==4.21.7
#   Downloading protobuf-4.21.7-cp37-abi3-manylinux2014_x86_64.whl (408 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.4/408.4 kB 42.9 MB/s eta 0:00:00
# Collecting psutil==5.9.2
#   Downloading psutil-5.9.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (281 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.3/281.3 kB 33.6 MB/s eta 0:00:00
# Collecting pyyaml==6.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.3/596.3 kB 54.8 MB/s eta 0:00:00
# Collecting seaborn==0.12.1
#   Downloading seaborn-0.12.1-py3-none-any.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 33.3 MB/s eta 0:00:00
# Collecting sentry-sdk==1.9.10
#   Downloading sentry_sdk-1.9.10-py2.py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.0/163.0 kB 23.1 MB/s eta 0:00:00
# Collecting setproctitle==1.3.2
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting shortuuid==1.0.9
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting smmap==5.0.0
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting timm==0.6.11
#   Downloading timm-0.6.11-py3-none-any.whl (548 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.7/548.7 kB 46.9 MB/s eta 0:00:00
# Collecting torchcam==0.3.2
#   Downloading torchcam-0.3.2-py3-none-any.whl (28 kB)
# Collecting tqdm==4.64.1
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 10.2 MB/s eta 0:00:00
# Collecting wandb==0.13.4
#   Downloading wandb-0.13.4-py2.py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 78.6 MB/s eta 0:00:00
# Collecting zipp==3.9.0
#   Downloading zipp-3.9.0-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: six>=1.4.0 in /usr/local/envs/egovision/lib/python3.7/site-packages (from docker-pycreds==0.4.0->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/envs/egovision/lib/python3.7/site-packages (from gdown==4.5.3->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 6)) (4.11.1)
# Requirement already satisfied: requests[socks] in /usr/local/envs/egovision/lib/python3.7/site-packages (from gdown==4.5.3->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 6)) (2.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/envs/egovision/lib/python3.7/site-packages (from gitpython==3.1.29->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 8)) (4.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/envs/egovision/lib/python3.7/site-packages (from huggingface-hub==0.10.1->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 9)) (21.3)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/envs/egovision/lib/python3.7/site-packages (from kneed==0.8.1->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 11)) (1.7.3)
# Requirement already satisfied: numpy>=1.14.2 in /usr/local/envs/egovision/lib/python3.7/site-packages (from kneed==0.8.1->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 11)) (1.21.5)
# Requirement already satisfied: pandas>=0.25 in /usr/local/envs/egovision/lib/python3.7/site-packages (from seaborn==0.12.1->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 18)) (1.3.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/envs/egovision/lib/python3.7/site-packages (from seaborn==0.12.1->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 18)) (3.5.2)
# Requirement already satisfied: urllib3>=1.26.11 in /usr/local/envs/egovision/lib/python3.7/site-packages (from sentry-sdk==1.9.10->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 19)) (1.26.11)
# Requirement already satisfied: certifi in /usr/local/envs/egovision/lib/python3.7/site-packages (from sentry-sdk==1.9.10->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 19)) (2022.9.24)
# Requirement already satisfied: torchvision in /usr/local/envs/egovision/lib/python3.7/site-packages (from timm==0.6.11->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 23)) (0.13.1)
# Requirement already satisfied: torch>=1.7 in /usr/local/envs/egovision/lib/python3.7/site-packages (from timm==0.6.11->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 23)) (1.12.1)
# Requirement already satisfied: Pillow>=8.3.2 in /usr/local/envs/egovision/lib/python3.7/site-packages (from torchcam==0.3.2->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 24)) (9.2.0)
# Requirement already satisfied: setuptools in /usr/local/envs/egovision/lib/python3.7/site-packages (from wandb==0.13.4->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 26)) (63.4.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/envs/egovision/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 18)) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/envs/egovision/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 18)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/envs/egovision/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 18)) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/envs/egovision/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 18)) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/envs/egovision/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 18)) (4.25.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/envs/egovision/lib/python3.7/site-packages (from pandas>=0.25->seaborn==0.12.1->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 18)) (2022.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/envs/egovision/lib/python3.7/site-packages (from requests[socks]->gdown==4.5.3->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/envs/egovision/lib/python3.7/site-packages (from requests[socks]->gdown==4.5.3->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 6)) (3.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/envs/egovision/lib/python3.7/site-packages (from beautifulsoup4->gdown==4.5.3->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 6)) (2.3.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/envs/egovision/lib/python3.7/site-packages (from requests[socks]->gdown==4.5.3->-r /content/deep-learning-egovision/condaenv.jydqlzsa.requirements.txt (line 6)) (1.7.1)
# Building wheels for collected packages: antlr4-python3-runtime, pathtools, promise
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=7ad5a483237f34c970971baf9f9c34ced9800308f4b03b85ba1b41af596c4b04
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
#   Building wheel for pathtools (setup.py): started
#   Building wheel for pathtools (setup.py): finished with status 'done'
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8792 sha256=5175f09227092af227aad50621c534dda7d3ac9334b87b8256ef64c849ea4f58
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
#   Building wheel for promise (setup.py): started
#   Building wheel for promise (setup.py): finished with status 'done'
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21486 sha256=0d5b1e7f89149d8b8a6f02dba9bef8e2af1c1ae63ddb1247a2111917d479385c
#   Stored in directory: /root/.cache/pip/wheels/29/93/c6/762e359f8cb6a5b69c72235d798804cae523bbe41c2aa8333d
# Successfully built antlr4-python3-runtime pathtools promise
# Installing collected packages: pathtools, antlr4-python3-runtime, zipp, tqdm, smmap, shortuuid, setproctitle, sentry-sdk, pyyaml, psutil, protobuf, promise, filelock, einops, docker-pycreds, omegaconf, kneed, importlib-metadata, gitdb, torchcam, seaborn, huggingface-hub, gitpython, gdown, wandb, timm
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.15.0
#     Uninstalling zipp-3.15.0:
#       Successfully uninstalled zipp-3.15.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.1
#     Uninstalling psutil-5.9.1:
#       Successfully uninstalled psutil-5.9.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
# Successfully installed antlr4-python3-runtime-4.9.3 docker-pycreds-0.4.0 einops-0.5.0 filelock-3.8.0 gdown-4.5.3 gitdb-4.0.9 gitpython-3.1.29 huggingface-hub-0.10.1 importlib-metadata-5.0.0 kneed-0.8.1 omegaconf-2.2.3 pathtools-0.1.2 promise-2.3 protobuf-4.21.7 psutil-5.9.2 pyyaml-6.0 seaborn-0.12.1 sentry-sdk-1.9.10 setproctitle-1.3.2 shortuuid-1.0.9 smmap-5.0.0 timm-0.6.11 torchcam-0.3.2 tqdm-4.64.1 wandb-0.13.4 zipp-3.9.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate egovision
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !cp /content/deep-learning-egovision/pretrained_i3d/rgb_imagenet.pt /content/deep-learning-egovision/pretrained_i3d/emg_imagenet.pt

# %%
# %%bash
# ## Features extraction
#
# cd /content/deep-learning-egovision
#
# PYTHON_PATH=/usr/local/envs/egovision/bin/python
# $PYTHON_PATH save_feat.py name=features_actionNet_uniform_15 \
#   config=configs/I3D_save_feat.yaml split=train \
#   dataset.shift=S0401-S0401 dataset.annotations_path=actionNet\
#   dataset.RGB.data_path=./actionNet/\
#   dataset.EMG.data_path=./actionNet/\
#   modality=["RGB","EMG"]
# Out:
# 2023-06-12 16:07:41 LOG INFO Feature Extraction
# 2023-06-12 16:07:41 LOG INFO Running with parameters:
#   action: save
#   name: features_actionNet_uniform_15
#   modality: ['RGB', 'EMG']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: None
#   logname: save_S0401-S0401.log
#   models_dir: saved_models/features_actionNet_uniform_15/Jun12_16-07-39
#   need_clips: False
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 5
#     dense_sampling:
#       RGB: False
#       EMG: None
#     num_frames_per_clip:
#       RGB: 15
#       EMG: None
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: False
#       EMG: None
#     num_frames_per_clip:
#       RGB: 15
#       EMG: None
#   dataset:
#     annotations_path: actionNet
#     shift: S0401-S0401
#     workers: 4
#     stride: 2
#     resolution: 224
#     RGB:
#       data_path: ./actionNet/
#       tmpl: img_{:010d}.jpg
#       features_name: features_D2_uniform_15
#     EMG:
#       data_path: ./actionNet/
#       tmpl: None
#       features_name: features_actionNet_uniform_15
#     Event:
#       rgb4e: 6
#   models:
#     RGB:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       n_features: 1024
#       hidden_size: 128
#       num_layers: 3
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#     EMG:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       n_features: 400
#       hidden_size: 128
#       num_layers: 3
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#   split: train
#   compute_accuracy: False
#   save:
#     num_clips: 5
#     dense_sampling:
#       RGB: False
#       EMG: None
#     num_frames_per_clip:
#       RGB: 15
#       EMG: None
#   config: configs/I3D_save_feat.yaml
#   experiment_dir: features_actionNet_uniform_15/Jun12_16-07-39
#   log_dir: TEST_RESULTS/features_actionNet_uniform_15
#   logfile: TEST_RESULTS/features_actionNet_uniform_15/save_S0401-S0401.log
# 2023-06-12 16:07:41 LOG INFO Instantiating models per modality
# 2023-06-12 16:07:41 LOG INFO I3D Net	Modality: RGB
# 2023-06-12 16:07:41 LOG INFO Loading Kinetics weights I3D
# 2023-06-12 16:07:41 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2023-06-12 16:07:41 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2023-06-12 16:07:41 LOG INFO I3D Net	Modality: EMG
# 2023-06-12 16:07:42 LOG INFO Loading Kinetics weights I3D
# 2023-06-12 16:07:42 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2023-06-12 16:07:42 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2023-06-12 16:07:43 LOG INFO Dataloader for S0401-train with 41 samples generated
# /usr/local/envs/egovision/lib/python3.7/site-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
# %%bash
# cd /content/deep-learning-egovision
#
# PYTHON_PATH=/usr/local/envs/egovision/bin/python
# $PYTHON_PATH save_feat.py name=features_actionNet_uniform_15 \
#   config=configs/I3D_save_feat.yaml split=test \
#   dataset.shift=S0401-S0401 dataset.annotations_path=actionNet\
#   dataset.RGB.data_path=./actionNet/\
#   dataset.EMG.data_path=./actionNet/\
#   modality=["RGB","EMG"]
# Out:
# 2023-06-12 16:09:35 LOG INFO Feature Extraction
# 2023-06-12 16:09:35 LOG INFO Running with parameters:
#   action: save
#   name: features_actionNet_uniform_15
#   modality: ['RGB', 'EMG']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: None
#   logname: save_S0401-S0401.log
#   models_dir: saved_models/features_actionNet_uniform_15/Jun12_16-09-34
#   need_clips: False
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 5
#     dense_sampling:
#       RGB: False
#       EMG: None
#     num_frames_per_clip:
#       RGB: 15
#       EMG: None
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: False
#       EMG: None
#     num_frames_per_clip:
#       RGB: 15
#       EMG: None
#   dataset:
#     annotations_path: actionNet
#     shift: S0401-S0401
#     workers: 4
#     stride: 2
#     resolution: 224
#     RGB:
#       data_path: ./actionNet/
#       tmpl: img_{:010d}.jpg
#       features_name: features_D2_uniform_15
#     EMG:
#       data_path: ./actionNet/
#       tmpl: None
#       features_name: features_actionNet_uniform_15
#     Event:
#       rgb4e: 6
#   models:
#     RGB:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       n_features: 1024
#       hidden_size: 128
#       num_layers: 3
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#     EMG:
#       model: I3D
#       normalize: False
#       kwargs:
#       lr_steps: 3000
#       lr: 0.01
#       sgd_momentum: 0.9
#       weight_decay: 1e-07
#       n_features: 400
#       hidden_size: 128
#       num_layers: 3
#       dropout: 0.5
#       resolution: 224
#       weight_i3d_rgb: ./pretrained_i3d/rgb_imagenet.pt
#   split: test
#   compute_accuracy: False
#   save:
#     num_clips: 5
#     dense_sampling:
#       RGB: False
#       EMG: None
#     num_frames_per_clip:
#       RGB: 15
#       EMG: None
#   config: configs/I3D_save_feat.yaml
#   experiment_dir: features_actionNet_uniform_15/Jun12_16-09-34
#   log_dir: TEST_RESULTS/features_actionNet_uniform_15
#   logfile: TEST_RESULTS/features_actionNet_uniform_15/save_S0401-S0401.log
# 2023-06-12 16:09:35 LOG INFO Instantiating models per modality
# 2023-06-12 16:09:35 LOG INFO I3D Net	Modality: RGB
# 2023-06-12 16:09:36 LOG INFO Loading Kinetics weights I3D
# 2023-06-12 16:09:36 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2023-06-12 16:09:36 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2023-06-12 16:09:36 LOG INFO I3D Net	Modality: EMG
# 2023-06-12 16:09:36 LOG INFO Loading Kinetics weights I3D
# 2023-06-12 16:09:36 LOG INFO  * Skipping Logits weight for 'logits.conv3d.weight'
# 2023-06-12 16:09:36 LOG INFO  * Skipping Logits weight for 'logits.conv3d.bias'
# 2023-06-12 16:09:37 LOG INFO Dataloader for S0401-test with 18 samples generated
# /usr/local/envs/egovision/lib/python3.7/site-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
# %%bash
# ## Features extraction
#
# cd /content/deep-learning-egovision
#
# PYTHON_PATH=/usr/local/envs/egovision/bin/python
# $PYTHON_PATH train_classifier.py name=lstm_emg_actionNet_train_uniform_15 \
#   dataset.shift=S0401-S0401 dataset.annotations_path=actionNet\
#   need_clips=True\
#   dataset.EMG.data_path=./actionNet/\
#   modality=["EMG"]
